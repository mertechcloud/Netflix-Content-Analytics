# %%
# Installing Required libraries to analyse the dataset 
# !pip install pandas 
# !pip install numpy
# !pip instaall matplotlib
# !pip install seaborn
# !pip install sqlite

# %%
Cell 1 now contains `import pandas as pd`. Note: in cell 0 there's a typo (`!pip instaall matplotlib`) and `sqlite` doesn't need pip. What would you like to do next?
